# %%
# 동영상 촬영 및 녹화, 저장_ (streamlit x)

import cv2

# 저장할 파일 이름 및 코덱 설정
output_filename = "interview_video.avi"
fps = 20.0
frame_size = (640, 480)  # 영상 크기 (가로, 세로)

# VideoWriter 객체 생성
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # 코덱: XVID
out = cv2.VideoWriter(output_filename, fourcc, fps, frame_size)

# 카메라 열기 (기본 장치: 0)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("웹캠을 열 수 없습니다.")
    exit()

print("녹화를 시작합니다. 종료하려면 'q' 키를 누르세요.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("프레임을 읽을 수 없습니다. 종료합니다.")
        break

    # 화면에 보여주기
    cv2.imshow('Recording...', frame)

    # 파일로 저장
    out.write(frame)

    # 종료 조건: q 키
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 리소스 해제
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"녹화가 완료되었습니다. 파일 저장 위치: {output_filename}")
# Out:
# 녹화를 시작합니다. 종료하려면 'q' 키를 누르세요.
# 녹화가 완료되었습니다. 파일 저장 위치: interview_video.avi

# %%
# Mediapipe로 얼굴 감정용 랜드마크 추적 _ (streamlit x)

import cv2
import mediapipe as mp

mp_face_mesh = mp.solutions.face_mesh
cap = cv2.VideoCapture(0)

with mp_face_mesh.FaceMesh(max_num_faces=1, refine_landmarks=True) as face_mesh:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        result = face_mesh.process(img_rgb)

        if result.multi_face_landmarks:
            for face_landmarks in result.multi_face_landmarks:
                mp.solutions.drawing_utils.draw_landmarks(
                    frame, face_landmarks, mp_face_mesh.FACEMESH_TESSELATION)

        cv2.imshow("FaceMesh Live", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# mediapipe face mesh -> 나오는 값으로 눈동자 -> 랜드마크 간 벡터 계산표정 감지 (웃음, 긴장 등)/	입꼬리, 눈꼬리, 턱 위치 분석
import cv2
import mediapipe as mp
import numpy as np

# 설정
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(max_num_faces=1)
mp_draw = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)

while True:
    ret, img = cap.read()
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(img_rgb)

    if results.multi_face_landmarks:
        for landmarks in results.multi_face_landmarks:
            # 눈, 입꼬리, 눈썹 등 특정 좌표 인덱스 추출
            h, w, _ = img.shape

            # 예: 왼쪽 눈동자 위치 (468 포인트 중 일부)
            left_eye_inner = landmarks.landmark[133]
            right_eye_inner = landmarks.landmark[362]
            nose_tip = landmarks.landmark[1]
            mouth_left = landmarks.landmark[61]
            mouth_right = landmarks.landmark[291]

            # 좌표 변환
            lx, ly = int(left_eye_inner.x * w), int(left_eye_inner.y * h)
            rx, ry = int(right_eye_inner.x * w), int(right_eye_inner.y * h)

            # 시선 방향 간단 판별 (눈동자 간 거리 등 비교)
            eye_dir = '정면'
            if lx - rx > 15:
                eye_dir = '왼쪽 봄'
            elif rx - lx > 15:
                eye_dir = '오른쪽 봄'

            # 입꼬리 높이 비교 → 웃음 여부 추정
            mx1 = int(mouth_left.y * h)
            mx2 = int(mouth_right.y * h)
            smile = abs(mx1 - mx2) < 5  # 웃을 땐 좌우 입꼬리 높이가 비슷

            # 피드백 출력
            feedback = f"{eye_dir}, {'웃음' if smile else '무표정'}"
            cv2.putText(img, feedback, (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)

            mp_draw.draw_landmarks(img, landmarks, mp_face_mesh.FACEMESH_CONTOURS)

    cv2.imshow("Live Feedback", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# mediapipe face mesh + 한글 폰트
import cv2
import mediapipe as mp
import numpy as np
from PIL import ImageFont, ImageDraw, Image

# -----------------------------
# [2단계] 한글 텍스트 출력 함수 정의
# -----------------------------
def draw_hangul_text(img, text, position, font_path, font_size=32, color=(0, 255, 0)):
    img_pil = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    draw = ImageDraw.Draw(img_pil)
    font = ImageFont.truetype(font_path, font_size)
    draw.text(position, text, font=font, fill=color)
    return cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)

# -----------------------------
# [1단계] FaceMesh 초기화
# -----------------------------
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(max_num_faces=1)
mp_drawing = mp.solutions.drawing_utils

# -----------------------------
# 웹캠 스트리밍 시작
# -----------------------------
cap = cv2.VideoCapture(0)
font_path = "C:/Windows/Fonts/malgun.ttf"  # 한글 폰트 경로

while cap.isOpened():
    success, img = cap.read()
    if not success:
        break

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(img_rgb)
    h, w, _ = img.shape

    feedback_text = "감지 안됨"

    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            mp_drawing.draw_landmarks(img, face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
                                      landmark_drawing_spec=mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=1, circle_radius=1))

            # 좌표 추출
            left_eye_inner = face_landmarks.landmark[133]
            right_eye_inner = face_landmarks.landmark[362]
            mouth_left = face_landmarks.landmark[61]
            mouth_right = face_landmarks.landmark[291]

            lx, ly = int(left_eye_inner.x * w), int(left_eye_inner.y * h)
            rx, ry = int(right_eye_inner.x * w), int(right_eye_inner.y * h)
            mx1 = int(mouth_left.y * h)
            mx2 = int(mouth_right.y * h)

            # -----------------------------
            # [3단계] 시선 방향 추정
            # -----------------------------
            eye_dir = "정면 응시"
            if lx - rx > 15:
                eye_dir = "왼쪽 응시"
            elif rx - lx > 15:
                eye_dir = "오른쪽 응시"

            # -----------------------------
            # 입꼬리 위치로 웃음 여부 추정
            # -----------------------------
            smile = abs(mx1 - mx2) < 5
            smile_text = "미소" if smile else "무표정"

            # -----------------------------
            # 피드백 한글 텍스트 생성
            # -----------------------------
            feedback_text = f"{eye_dir}, {smile_text}"

    # -----------------------------
    # 한글 텍스트 이미지에 출력
    # -----------------------------
    img = draw_hangul_text(img, feedback_text, (30, 50), font_path)

    cv2.imshow("Live Feedback", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# !pip uninstall opencv-python opencv-contrib-python -y
# Out:
# WARNING: Skipping opencv-python as it is not installed.
# WARNING: Skipping opencv-contrib-python as it is not installed.

# %%
# !pip install opencv-python opencv-contrib-python --no-cache-dir --force-reinstall
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/39.0 MB 12.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.2/39.0 MB 12.8 MB/s eta 0:00:03
#    ------- -------------------------------- 7.1/39.0 MB 11.2 MB/s eta 0:00:03
#    --------- ------------------------------ 9.7/39.0 MB 11.6 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/39.0 MB 11.9 MB/s eta 0:00:03
#    -------------- ------------------------- 14.2/39.0 MB 11.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.5/39.0 MB 11.4 MB/s eta 0:00:02
#    ------------------- -------------------- 19.1/39.0 MB 11.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.8/39.0 MB 11.7 MB/s eta 0:00:02
#    ------------------------- -------------- 24.4/39.0 MB 11.8 MB/s eta 0:00:02
#    --------------------------- ------------ 26.7/39.0 MB 11.8 MB/s eta 0:00:02
#    ------------------------------ --------- 29.4/39.0 MB 11.8 MB/s eta 0:00:01
#    -------------------------------- ------- 32.0/39.0 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/39.0 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/39.0 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 12.0 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.6/12.9 MB 12.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.9 MB 12.2 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.9 MB 12.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 12.4 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.12.0.88-cp37-abi3-win_amd64.whl (45.3 MB)
#    ---------------------------------------- 0.0/45.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/45.3 MB 12.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.2/45.3 MB 12.7 MB/s eta 0:00:04
#    ------ --------------------------------- 7.6/45.3 MB 12.7 MB/s eta 0:00:03
#    --------- ------------------------------ 10.2/45.3 MB 12.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.6/45.3 MB 12.5 MB/s eta 0:00:03
#    ------------- -------------------------- 15.2/45.3 MB 12.3 MB/s eta 0:00:03
#    --------------- ------------------------ 17.8/45.3 MB 12.4 MB/s eta 0:00:03
#    ------------------ --------------------- 20.4/45.3 MB 12.3 MB/s eta 0:00:03
#    -------------------- ------------------- 23.1/45.3 MB 12.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.7/45.3 MB 12.3 MB/s eta 0:00:02
#    ------------------------- -------------- 28.3/45.3 MB 12.3 MB/s eta 0:00:02
#    --------------------------- ------------ 30.7/45.3 MB 12.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.3/45.3 MB 12.3 MB/s eta 0:00:01
#    ------------------------------- -------- 35.9/45.3 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.5/45.3 MB 12.3 MB/s eta 0:00:01
#    ------------------------------------ --- 41.2/45.3 MB 12.3 MB/s eta 0:00:01
#    -------------------------------------- - 44.0/45.3 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 45.3/45.3 MB 12.4 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python, opencv-contrib-python
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.1.3
#
#    ---------------------------------------- 0/3 [numpy]
#     Uninstalling numpy-2.1.3:
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#       Successfully uninstalled numpy-2.1.3
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    ------------- -------------------------- 1/3 [opencv-python]
#    -------------------------- ------------- 2/3 [opencv-contrib-python]
#    -------------------------- ------------- 2/3 [opencv-contrib-python]
#    -------------------------- ------------- 2/3 [opencv-contrib-python]
#    -------------------------- ------------- 2/3 [opencv-contrib-python]
#    -------------------------- ------------- 2/3 [opencv-contrib-python]
#    ---------------------------------------- 3/3 [opencv-contrib-python]
#
# Successfully installed numpy-2.2.6 opencv-contrib-python-4.12.0.88 opencv-python-4.12.0.88
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.

# %%
# !pip install numpy==1.26.4 --force-reinstall
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
# !pip uninstall opencv-python opencv-contrib-python numpy -y
# Out:
# Found existing installation: opencv-python 4.12.0.88
# Uninstalling opencv-python-4.12.0.88:
#   Successfully uninstalled opencv-python-4.12.0.88
# Found existing installation: opencv-contrib-python 4.12.0.88
# Uninstalling opencv-contrib-python-4.12.0.88:
#   Successfully uninstalled opencv-contrib-python-4.12.0.88
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4

# %%
# !pip install deepface --no-cache-dir --force-reinstall
# Out:
# Collecting deepface
#   Downloading deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# Collecting requests>=2.27.1 (from deepface)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting numpy>=1.14.0 (from deepface)
#   Downloading numpy-2.3.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting pandas>=0.23.4 (from deepface)
#   Downloading pandas-2.3.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting tqdm>=4.30.0 (from deepface)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting Pillow>=5.2.0 (from deepface)
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting opencv-python>=4.5.5.64 (from deepface)
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting tensorflow>=1.9.0 (from deepface)
#   Downloading tensorflow-2.19.0-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting keras>=2.2.0 (from deepface)
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting Flask>=1.1.2 (from deepface)
#   Downloading flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting termcolor (from fire>=0.4.0->deepface)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting blinker>=1.9.0 (from Flask>=1.1.2->deepface)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from Flask>=1.1.2->deepface)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting itsdangerous>=2.2.0 (from Flask>=1.1.2->deepface)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from Flask>=1.1.2->deepface)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask>=1.1.2->deepface)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting werkzeug>=3.1.0 (from Flask>=1.1.2->deepface)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting colorama (from click>=8.1.3->Flask>=1.1.2->deepface)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting beautifulsoup4 (from gdown>=3.10.1->deepface)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown>=3.10.1->deepface)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting packaging (from gunicorn>=20.1.0->deepface)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting absl-py (from keras>=2.2.0->deepface)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting rich (from keras>=2.2.0->deepface)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=2.2.0->deepface)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting h5py (from keras>=2.2.0->deepface)
#   Downloading h5py-3.14.0-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# Collecting optree (from keras>=2.2.0->deepface)
#   Downloading optree-0.17.0-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting ml-dtypes (from keras>=2.2.0->deepface)
#   Downloading ml_dtypes-0.5.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting joblib>=1.4.2 (from mtcnn>=0.1.0->deepface)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting lz4>=4.3.3 (from mtcnn>=0.1.0->deepface)
#   Downloading lz4-4.4.4-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting numpy>=1.14.0 (from deepface)
#   Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>=0.23.4->deepface)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=0.23.4->deepface)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=0.23.4->deepface)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=0.23.4->deepface)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.27.1->deepface)
#   Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.27.1->deepface)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.27.1->deepface)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.27.1->deepface)
#   Downloading certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting astunparse>=1.6.0 (from tensorflow>=1.9.0->deepface)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow>=1.9.0->deepface)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow>=1.9.0->deepface)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow>=1.9.0->deepface)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow>=1.9.0->deepface)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow>=1.9.0->deepface)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow>=1.9.0->deepface)
#   Downloading protobuf-5.29.5-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting setuptools (from tensorflow>=1.9.0->deepface)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow>=1.9.0->deepface)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.11.0 (from tensorflow>=1.9.0->deepface)
#   Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow>=1.9.0->deepface)
#   Downloading grpcio-1.74.0-cp311-cp311-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow>=1.9.0->deepface)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting numpy>=1.14.0 (from deepface)
#   Downloading numpy-2.1.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow>=1.9.0->deepface)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface)
#   Downloading markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown>=3.10.1->deepface)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown>=3.10.1->deepface)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=2.2.0->deepface)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->keras>=2.2.0->deepface)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading deepface-0.0.93-py3-none-any.whl (108 kB)
# Downloading flask-3.1.1-py3-none-any.whl (103 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 8.9 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 11.7 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading lz4-4.4.4-cp311-cp311-win_amd64.whl (99 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/39.0 MB 12.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.0/39.0 MB 12.1 MB/s eta 0:00:03
#    -------- ------------------------------- 7.9/39.0 MB 12.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.2/39.0 MB 12.3 MB/s eta 0:00:03
#    ------------- -------------------------- 12.8/39.0 MB 12.4 MB/s eta 0:00:03
#    --------------- ------------------------ 15.5/39.0 MB 12.5 MB/s eta 0:00:02
#    ------------------ --------------------- 17.8/39.0 MB 12.5 MB/s eta 0:00:02
#    -------------------- ------------------- 20.4/39.0 MB 12.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.1/39.0 MB 12.5 MB/s eta 0:00:02
#    -------------------------- ------------- 25.7/39.0 MB 12.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.0/39.0 MB 12.5 MB/s eta 0:00:01
#    ------------------------------- -------- 30.7/39.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.3/39.0 MB 12.5 MB/s eta 0:00:01
#    ------------------------------------ --- 35.9/39.0 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------
MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 12.3 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp311-cp311-win_amd64.whl (209 kB)
# Downloading numpy-2.1.3-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.9 MB 12.2 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.9 MB 12.6 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.9 MB 12.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 12.6 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp310-abi3-win_amd64.whl (434 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ------------------- -------------------- 2.6/5.5 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 12.4 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.14.0-cp311-cp311-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------------------------------------ --- 2.6/2.9 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 12.9 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    --- ------------------------------------ 2.6/26.4 MB 13.7 MB/s eta 0:00:02
#    ------- -------------------------------- 5.2/26.4 MB 12.8 MB/s eta 0:00:02
#    ------------ --------------------------- 8.1/26.4 MB 12.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.7/26.4 MB 12.9 MB/s eta 0:00:02
#    ------------------- -------------------- 13.1/26.4 MB 12.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.7/26.4 MB 12.9 MB/s eta 0:00:01
#    --------------------------- ------------ 18.4/26.4 MB 12.7 MB/s eta 0:00:01
#    ------------------------------- -------- 21.0/26.4 MB 12.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.6/26.4 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 12.7 MB/s eta 0:00:00
# Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.0 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 11.2 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl (38 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp311-cp311-win_amd64.whl (313 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 12.3 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114349 sha256=b58e3f23d942223fb0b40ddb1554d1176dcab44f52690f3e37a905af36d06bf5
#   Stored in directory: C:\Users\Mira\AppData\Local\Temp\pip-ephem-wheel-cache-y14vay01\wheels\46\54\24\1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: pytz, namex, libclang, flatbuffers, wrapt, wheel, urllib3, tzdata, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, soupsieve, six, setuptools, PySocks, pygments, protobuf, Pillow, packaging, opt-einsum, numpy, mdurl, markupsafe, markdown, lz4, joblib, itsdangerous, idna, grpcio, gast, filelock, colorama, charset_normalizer, certifi, blinker, absl-py, werkzeug, tqdm, requests, python-dateutil, optree, opencv-python, mtcnn, ml-dtypes, markdown-it-py, jinja2, h5py, gunicorn, google-pasta, fire, click, beautifulsoup4, astunparse, tensorboard, rich, pandas, Flask, keras, gdown, flask-cors, tensorflow, retina-face, deepface
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2025.2
#
#     Uninstalling pytz-2025.2:
#
#       Successfully uninstalled pytz-2025.2
#
#    ----------------------------------------  0/64 [pytz]
#    ----------------------------------------  0/64 [pytz]
#    ----------------------------------------  0/64 [pytz]
#    ----------------------------------------  0/64 [pytz]
#    ----------------------------------------  0/64 [pytz]
#   Attempting uninstall: namex
#    ----------------------------------------  0/64 [pytz]
#     Found existing installation: namex 0.1.0
#    ----------------------------------------  0/64 [pytz]
#     Uninstalling namex-0.1.0:
#    ----------------------------------------  0/64 [pytz]
#       Successfully uninstalled namex-0.1.0
#    ----------------------------------------  0/64 [pytz]
#     ---------------------------------------  1/64 [namex]
#   Attempting uninstall: libclang
#     ---------------------------------------  1/64 [namex]
#     Found existing installation: libclang 18.1.1
#     ---------------------------------------  1/64 [namex]
#     Uninstalling libclang-18.1.1:
#     ---------------------------------------  1/64 [namex]
#       Successfully uninstalled libclang-18.1.1
#     ---------------------------------------  1/64 [namex]
#    - --------------------------------------  2/64 [libclang]
#    - --------------------------------------  2/64 [libclang]
#    - --------------------------------------  2/64 [libclang]
#    - --------------------------------------  2/64 [libclang]
#    - --------------------------------------  2/64 [libclang]
#    - --------------------------------------  2/64 [libclang]
#   Attempting uninstall: flatbuffers
#    - --------------------------------------  2/64 [libclang]
#     Found existing installation: flatbuffers 25.2.10
#    - --------------------------------------  2/64 [libclang]
#     Uninstalling flatbuffers-25.2.10:
#    - --------------------------------------  2/64 [libclang]
#       Successfully uninstalled flatbuffers-25.2.10
#    - --------------------------------------  2/64 [libclang]
#    - --------------------------------------  3/64 [flatbuffers]
#   Attempting uninstall: wrapt
#    - --------------------------------------  3/64 [flatbuffers]
#     Found existing installation: wrapt 1.17.2
#    - --------------------------------------  3/64 [flatbuffers]
#     Uninstalling wrapt-1.17.2:
#    - --------------------------------------  3/64 [flatbuffers]
#       Successfully uninstalled wrapt-1.17.2
#    - --------------------------------------  3/64 [flatbuffers]
#   Attempting uninstall: wheel
#    - --------------------------------------  3/64 [flatbuffers]
#     Found existing installation: wheel 0.45.1
#    - --------------------------------------  3/64 [flatbuffers]
#    --- ------------------------------------  5/64 [wheel]
#     Uninstalling wheel-0.45.1:
#    --- ------------------------------------  5/64 [wheel]
#       Successfully uninstalled wheel-0.45.1
#    --- ------------------------------------  5/64 [wheel]
#    --- ------------------------------------  5/64 [wheel]
#    --- ------------------------------------  5/64 [wheel]
#   Attempting uninstall: urllib3
#    --- ------------------------------------  5/64 [wheel]
#     Found existing installation: urllib3 2.5.0
#    --- ------------------------------------  5/64 [wheel]
#     Uninstalling urllib3-2.5.0:
#    --- ------------------------------------  5/64 [wheel]
#       Successfully uninstalled urllib3-2.5.0
#    --- ------------------------------------  5/64 [wheel]
#    --- ------------------------------------  6/64 [urllib3]
#    --- ------------------------------------  6/64 [urllib3]
#   Attempting uninstall: tzdata
#    --- ------------------------------------  6/64 [urllib3]
#     Found existing installation: tzdata 2025.2
#    --- ------------------------------------  6/64 [urllib3]
#    ---- -----------------------------------  7/64 [tzdata]
#     Uninstalling tzdata-2025.2:
#    ---- -----------------------------------  7/64 [tzdata]
#    ---- -----------------------------------  7/64 [tzdata]
#       Successfully uninstalled tzdata-2025.2
#    ---- -----------------------------------  7/64 [tzdata]
#    ---- -----------------------------------  7/64 [tzdata]
#    ---- -----------------------------------  7/64 [tzdata]
#    ---- -----------------------------------  7/64 [tzdata]
#    ---- -----------------------------------  7/64 [tzdata]
#    ---- -----------------------------------  7/64 [tzdata]
#   Attempting uninstall: typing-extensions
#    ---- -----------------------------------  7/64 [tzdata]
#     Found existing installation: typing_extensions 4.12.2
#    ---- -----------------------------------  7/64 [tzdata]
#     Uninstalling typing_extensions-4.12.2:
#    ---- -----------------------------------  7/64 [tzdata]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  8/64 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ----- ----------------------------------  8/64 [typing-extensions]
#   Attempting uninstall: termcolor
#    ----- ----------------------------------  8/64 [typing-extensions]
#    ----- ----------------------------------  9/64 [termcolor]
#     Found existing installation: termcolor 3.1.0
#    ----- ----------------------------------  9/64 [termcolor]
#     Uninstalling termcolor-3.1.0:
#    ----- ----------------------------------  9/64 [termcolor]
#       Successfully uninstalled termcolor-3.1.0
#    ----- ----------------------------------  9/64 [termcolor]
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#    ----- ----------------------------------  9/64 [termcolor]
#     Found existing installation: tensorflow-io-gcs-filesystem 0.31.0
#    ----- ----------------------------------  9/64 [termcolor]
#     Uninstalling tensorflow-io-gcs-filesystem-0.31.0:
#    ----- ----------------------------------  9/64 [termcolor]
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.31.0
#    ----- ----------------------------------  9/64 [termcolor]
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#   Attempting uninstall: tensorboard-data-server
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#     Found existing installation: tensorboard-data-server 0.7.2
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#     Uninstalling tensorboard-data-server-0.7.2:
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#       Successfully uninstalled tensorboard-data-server-0.7.2
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#   Attempting uninstall: soupsieve
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#     Found existing installation: soupsieve 2.7
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#     Uninstalling soupsieve-2.7:
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#       Successfully uninstalled soupsieve-2.7
#    ------ -------------------------------- 10/64 [tensorflow-io-gcs-filesystem]
#    ------- -------------------------------- 12/64 [soupsieve]
#   Attempting uninstall: six
#    ------- -------------------------------- 12/64 [soupsieve]
#     Found existing installation: six 1.17.0
#    ------- -------------------------------- 12/64 [soupsieve]
#     Uninstalling six-1.17.0:
#    ------- -------------------------------- 12/64 [soupsieve]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#       Successfully uninstalled six-1.17.0
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 13/64 [six]
#   Attempting uninstall: setuptools
#    -------- ------------------------------- 13/64 [six]
#     Found existing installation: setuptools 78.1.1
#    -------- ------------------------------- 13/64 [six]
#     Uninstalling setuptools-78.1.1:
#    -------- ------------------------------- 13/64 [six]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#       Successfully uninstalled setuptools-78.1.1
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#    -------- ------------------------------- 14/64 [setuptools]
#   Attempting uninstall: PySocks
#    -------- ------------------------------- 14/64 [setuptools]
#     Found existing installation: PySocks 1.7.1
#    -------- ------------------------------- 14/64 [setuptools]
#     Uninstalling PySocks-1.7.1:
#    -------- ------------------------------- 14/64 [setuptools]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#    --------- ------------------------------ 15/64 [PySocks]
#       Successfully uninstalled PySocks-1.7.1
#    --------- ------------------------------ 15/64 [PySocks]
#   Attempting uninstall: pygments
#    --------- ------------------------------ 15/64 [PySocks]
#     Found existing installation: Pygments 2.19.1
#    --------- ------------------------------ 15/64 [PySocks]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#     Uninstalling Pygments-2.19.1:
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#       Successfully uninstalled Pygments-2.19.1
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 16/64 [pygments]
#   Attempting uninstall: protobuf
#    ---------- ----------------------------- 16/64 [pygments]
#     Found existing installation: protobuf 4.25.8
#    ---------- ----------------------------- 16/64 [pygments]
#     Uninstalling protobuf-4.25.8:
#    ---------- ----------------------------- 16/64 [pygments]
#    ---------- ----------------------------- 17/64 [protobuf]
#       Successfully uninstalled protobuf-4.25.8
#    ---------- ----------------------------- 17/64 [protobuf]
#    ---------- ----------------------------- 17/64 [protobuf]
#    ---------- ----------------------------- 17/64 [protobuf]
#    ---------- ----------------------------- 17/64 [protobuf]
#   Attempting uninstall: Pillow
#    ---------- ----------------------------- 17/64 [protobuf]
#     Found existing installation: pillow 11.3.0
#    ---------- ----------------------------- 17/64 [protobuf]
#    ----------- ---------------------------- 18/64 [Pillow]
#     Uninstalling pillow-11.3.0:
#    ----------- ---------------------------- 18/64 [Pillow]
#       Successfully uninstalled pillow-11.3.0
#    ----------- ---------------------------- 18/64 [Pillow]
#    ----------- ---------------------------- 18/64 [Pillow]
#    ----------- ---------------------------- 18/64 [Pillow]
#    ----------- ---------------------------- 18/64 [Pillow]
#    ----------- ---------------------------- 18/64 [Pillow]
#    ----------- ---------------------------- 18/64 [Pillow]
#    ----------- ---------------------------- 18/64 [Pillow]
#   Attempting uninstall: packaging
#    ----------- ---------------------------- 18/64 [Pillow]
#     Found existing installation: packaging 24.2
#    ----------- ---------------------------- 18/64 [Pillow]
#    ----------- ---------------------------- 19/64 [packaging]
#     Uninstalling packaging-24.2:
#    ----------- ---------------------------- 19/64 [packaging]
#       Successfully uninstalled packaging-24.2
#    ----------- ---------------------------- 19/64 [packaging]
#    ----------- ---------------------------- 19/64 [packaging]
#   Attempting uninstall: opt-einsum
#    ----------- ---------------------------- 19/64 [packaging]
#     Found existing installation: opt_einsum 3.4.0
#    ----------- ---------------------------- 19/64 [packaging]
#    ------------ --------------------------- 20/64 [opt-einsum]
#     Uninstalling opt_einsum-3.4.0:
#    ------------ --------------------------- 20/64 [opt-einsum]
#       Successfully uninstalled opt_einsum-3.4.0
#    ------------ --------------------------- 20/64 [opt-einsum]
#    ------------ --------------------------- 20/64 [opt-einsum]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
#    ------------- -------------------------- 21/64 [numpy]
# ...
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#     Uninstalling tensorflow-2.19.0:
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#       Successfully uninstalled tensorflow-2.19.0
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    -------------------------------------- - 61/64 [tensorflow]
#    ---------------------------------------  63/64 [deepface]
#    ---------------------------------------  63/64 [deepface]
#    ---------------------------------------- 64/64 [deepface]
#
# Successfully installed Flask-3.1.1 Pillow-11.3.0 PySocks-1.7.1 absl-py-2.3.1 astunparse-1.6.3 beautifulsoup4-4.13.4 blinker-1.9.0 certifi-2025.7.14 charset_normalizer-3.4.2 click-8.2.1 colorama-0.4.6 deepface-0.0.93 filelock-3.18.0 fire-0.7.0 flask-cors-6.0.1 flatbuffers-25.2.10 gast-0.6.0 gdown-5.2.0 google-pasta-0.2.0 grpcio-1.74.0 gunicorn-23.0.0 h5py-3.14.0 idna-3.10 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.1 keras-3.10.0 libclang-18.1.1 lz4-4.4.4 markdown-3.8.2 markdown-it-py-3.0.0 markupsafe-3.0.2 mdurl-0.1.2 ml-dtypes-0.5.1 mtcnn-1.0.0 namex-0.1.0 numpy-2.1.3 opencv-python-4.12.0.88 opt-einsum-3.4.0 optree-0.17.0 packaging-25.0 pandas-2.3.1 protobuf-5.29.5 pygments-2.19.2 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.4 retina-face-0.0.17 rich-14.1.0 setuptools-80.9.0 six-1.17.0 soupsieve-2.7 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.1.0 tqdm-4.67.1 typing-extensions-4.14.1 tzdata-2025.2 urllib3-2.5.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2
#   DEPRECATION: Building 'fire' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'fire'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires opencv-contrib-python, which is not installed.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.1.3 which is incompatible.
# mediapipe 0.10.21 requires protobuf<5,>=4.25.3, but you have protobuf 5.29.5 which is incompatible.

# %%
pip install numpy==1.26.4

# %%
pip install opencv-python==4.7.0.72

# %%
pip install opencv-contrib-python==4.7.0.72

# %%
pip install tensorflow==2.19.0

# %%
pip install mediapipe==0.10.21

# %%
pip install deepface

# %%
# 시선 추적 및 표전 분석용 모델 적용 _ emotion_model.h5 없음

import cv2
import mediapipe as mp
import numpy as np
import tensorflow as tf
import time

# 🧠 감정 라벨 정의
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# 🧠 학습된 CNN 모델 불러오기
emotion_model = tf.keras.models.load_model('emotion_model.h5')

# 🎯 Face Mesh 설정
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
                                   refine_landmarks=True,
                                   max_num_faces=1,
                                   min_detection_confidence=0.5,
                                   min_tracking_confidence=0.5)

# 🎯 MediaPipe 얼굴 감지용 (표정 분석용)
mp_face_detection = mp.solutions.face_detection
face_detection = mp_face_detection.FaceDetection(model_selection=0, min_detection_confidence=0.5)

# 👁️ 눈 및 동공 좌표 인덱스
LEFT_EYE = [33, 133]
RIGHT_EYE = [362, 263]
LEFT_IRIS = [468, 469, 470, 471]
RIGHT_IRIS = [473, 474, 475, 476]

def calc_gaze_ratio(iris, eye):
    center = np.mean(iris, axis=0)
    left, right = eye
    return (center[0] - left[0]) / (right[0] - left[0])

def get_emotion(face_img):
    gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray, (48, 48)) / 255.0
    input_img = resized.reshape(1, 48, 48, 1)
    prediction = emotion_model.predict(input_img, verbose=0)
    return emotion_labels[np.argmax(prediction)]

# 🎥 카메라 시작
cap = cv2.VideoCapture(0)
prev_time = time.time()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame = cv2.flip(frame, 1)
    h, w = frame.shape[:2]
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # 시선 분석
    results = face_mesh.process(rgb)
    gaze_text = "시선 감지 중..."

    if results.multi_face_landmarks:
        landmarks = results.multi_face_landmarks[0].landmark

        def extract(index_list):
            return np.array([[int(landmarks[i].x * w), int(landmarks[i].y * h)] for i in index_list])

        left_eye = extract(LEFT_EYE)
        right_eye = extract(RIGHT_EYE)
        left_iris = extract(LEFT_IRIS)
        right_iris = extract(RIGHT_IRIS)

        left_ratio = calc_gaze_ratio(left_iris, left_eye)
        right_ratio = calc_gaze_ratio(right_iris, right_eye)
        avg_ratio = (left_ratio + right_ratio) / 2

        if avg_ratio < 0.25:
            gaze_text = "시선: 왼쪽 화면 밖"
        elif avg_ratio > 0.75:
            gaze_text = "시선: 오른쪽 화면 밖"
        else:
            gaze_text = "시선: 화면 중앙"

    # 표정 감정 분석 (0.2초 간격)
    now = time.time()
    if now - prev_time >= 0.2:
        emotion_text = "표정 분석 중..."
        results_fd = face_detection.process(rgb)
        if results_fd.detections:
            for detection in results_fd.detections:
                bboxC = detection.location_data.relative_bounding_box
                x, y = int(bboxC.xmin * w), int(bboxC.ymin * h)
                w_box, h_box = int(bboxC.width * w), int(bboxC.height * h)
                face_img = frame[y:y+h_box, x:x+w_box]
                if face_img.size > 0:
                    emotion_text = get_emotion(face_img)
                    cv2.putText(frame, f'감정: {emotion_text}', (x, y-10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 200, 0), 2)
                    cv2.rectangle(frame, (x, y), (x+w_box, y+h_box), (255, 200, 0), 2)
        prev_time = now

    # 결과 시각화
    cv2.putText(frame, gaze_text, (30, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    cv2.imshow("시선 및 표정 분석", frame)

    if cv2.waitKey(1) & 0xFF == 27:  # ESC 키 종료
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 11
#       8 emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
#      10 # 🧠 학습된 CNN 모델 불러오기
# ---> 11 emotion_model = tf.keras.models.load_model('emotion_model.h5')
#      13 # 🎯 Face Mesh 설정
#      14 mp_face_mesh = mp.solutions.face_mesh
#
# File c:\Users\Mira\miniconda3\envs\interview_env\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File c:\Users\Mira\miniconda3\envs\interview_env\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File c:\Users\Mira\miniconda3\envs\interview_env\Lib\site-packages\h5py\_hl\files.py:564, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     555     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     556                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     557                      alignment_threshold=alignment_threshold,
#     558                      alignment_interval=alignment_interval,
#     559                      meta_block_size=meta_block_size,
#     560                      **kwds)
#     561     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     562                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                      fs_page_size=fs_page_size)
# --> 564     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     566 if isinstance(libver, tuple):
#     567     self._libver = libver
#
# File c:\Users\Mira\miniconda3\envs\interview_env\Lib\site-packages\h5py\_hl\files.py:238, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236     if swmr and swmr_support:
#     237         flags |= h5f.ACC_SWMR_READ
# --> 238     fid = h5f.open(name, flags, fapl=fapl)
#     239 elif mode == 'r+':
#     240     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'emotion_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
# !pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.93-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from deepface) (2.32.4)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from deepface) (2.3.1)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from deepface) (4.67.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from deepface) (11.3.0)
# Collecting opencv-python>=4.5.5.64 (from deepface)
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from deepface) (2.19.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from deepface) (3.10.0)
# Collecting Flask>=1.1.2 (from deepface)
#   Downloading flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: termcolor in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from fire>=0.4.0->deepface) (3.1.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from Flask>=1.1.2->deepface) (8.2.1)
# Collecting itsdangerous>=2.2.0 (from Flask>=1.1.2->deepface)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: colorama in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from click>=8.1.3->Flask>=1.1.2->deepface) (0.4.6)
# Collecting beautifulsoup4 (from gdown>=3.10.1->deepface)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: filelock in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: packaging in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from gunicorn>=20.1.0->deepface) (24.2)
# Requirement already satisfied: absl-py in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from keras>=2.2.0->deepface) (2.3.1)
# Requirement already satisfied: rich in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from keras>=2.2.0->deepface) (14.1.0)
# Requirement already satisfied: namex in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from keras>=2.2.0->deepface) (0.1.0)
# Requirement already satisfied: h5py in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from keras>=2.2.0->deepface) (3.14.0)
# Requirement already satisfied: optree in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from keras>=2.2.0->deepface) (0.17.0)
# Requirement already satisfied: ml-dtypes in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from keras>=2.2.0->deepface) (0.5.1)
# Collecting joblib>=1.4.2 (from mtcnn>=0.1.0->deepface)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting lz4>=4.3.3 (from mtcnn>=0.1.0->deepface)
#   Downloading lz4-4.4.4-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting numpy>=1.14.0 (from deepface)
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23.4->deepface) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from requests>=2.27.1->deepface) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from requests>=2.27.1->deepface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from requests>=2.27.1->deepface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from requests>=2.27.1->deepface) (2025.7.14)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.25.8)
# Requirement already satisfied: setuptools in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (78.1.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.19.0)
#   Using cached numpy-2.1.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown>=3.10.1->deepface)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown>=3.10.1->deepface)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mira\miniconda3\envs\interview_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Downloading deepface-0.0.93-py3-none-any.whl (108 kB)
# Downloading flask-3.1.1-py3-none-any.whl (103 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 10.5 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading lz4-4.4.4-cp311-cp311-win_amd64.whl (99 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Using cached numpy-2.1.3-cp311-cp311-win_amd64.whl (12.9 MB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114349 sha256=ff227dcd1eebdd77cdbbcb272ffa4fccbddb19c416548b46bd15cd49b6b7b766
#   Stored in directory: c:\users\mira\appdata\local\pip\cache\wheels\46\54\24\1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: soupsieve, PySocks, numpy, lz4, joblib, itsdangerous, gunicorn, fire, opencv-python, mtcnn, Flask, beautifulsoup4, gdown, flask-cors, retina-face, deepface
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 1.26.4
#
#    ----- ----------------------------------  2/16 [numpy]
#     Uninstalling numpy-1.26.4:
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#       Successfully uninstalled numpy-1.26.4
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ----- ----------------------------------  2/16 [numpy]
#    ---------- -----------------------------  4/16 [joblib]
#    ---------- -----------------------------  4/16 [joblib]
#    --------------- ------------------------  6/16 [gunicorn]
#    ----------------- ----------------------  7/16 [fire]
#    -------------------- -------------------  8/16 [opencv-python]
#   DEPRECATION: Building 'fire' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'fire'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Mira\miniconda3\envs\interview_env\Lib\site-packages\~~mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Mira\miniconda3\envs\interview_env\Lib\site-packages\~.mpy'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\Mira\\miniconda3\\envs\\interview_env\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# 시선 추적 및 표전 분석용 모델 적용 _ emotion_model.h5 없어서 deepface 로 변경
import cv2
import mediapipe as mp
import numpy as np
import time
from deepface import DeepFace  # ✅ DeepFace 추가

# 👁️ 눈 및 동공 좌표 인덱스
LEFT_EYE = [33, 133]
RIGHT_EYE = [362, 263]
LEFT_IRIS = [468, 469, 470, 471]
RIGHT_IRIS = [473, 474, 475, 476]

# 🎯 Face Mesh 설정
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
                                   refine_landmarks=True,
                                   max_num_faces=1,
                                   min_detection_confidence=0.5,
                                   min_tracking_confidence=0.5)

# 🎯 얼굴 감지용
mp_face_detection = mp.solutions.face_detection
face_detection = mp_face_detection.FaceDetection(model_selection=0, min_detection_confidence=0.5)

# 🧠 시선 계산
def calc_gaze_ratio(iris, eye):
    center = np.mean(iris, axis=0)
    left, right = eye
    return (center[0] - left[0]) / (right[0] - left[0])

# ✅ DeepFace 기반 감정 분석 함수
def get_emotion(face_img):
    try:
        result = DeepFace.analyze(face_img, actions=['emotion'], enforce_detection=False)
        emotion = result[0]['dominant_emotion']
        return emotion
    except Exception as e:
        print("감정 분석 오류:", e)
        return "분석 실패"

# 🎥 카메라 시작
cap = cv2.VideoCapture(0)
prev_time = time.time()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame = cv2.flip(frame, 1)
    h, w = frame.shape[:2]
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # 시선 분석
    results = face_mesh.process(rgb)
    gaze_text = "시선 감지 중..."

    if results.multi_face_landmarks:
        landmarks = results.multi_face_landmarks[0].landmark

        def extract(index_list):
            return np.array([[int(landmarks[i].x * w), int(landmarks[i].y * h)] for i in index_list])

        left_eye = extract(LEFT_EYE)
        right_eye = extract(RIGHT_EYE)
        left_iris = extract(LEFT_IRIS)
        right_iris = extract(RIGHT_IRIS)

        left_ratio = calc_gaze_ratio(left_iris, left_eye)
        right_ratio = calc_gaze_ratio(right_iris, right_eye)
        avg_ratio = (left_ratio + right_ratio) / 2

        if avg_ratio < 0.25:
            gaze_text = "시선: 왼쪽 화면 밖"
        elif avg_ratio > 0.75:
            gaze_text = "시선: 오른쪽 화면 밖"
        else:
            gaze_text = "시선: 화면 중앙"

    # 감정 분석 (0.5초 간격)
    now = time.time()
    if now - prev_time >= 0.5:
        emotion_text = "표정 분석 중..."
        results_fd = face_detection.process(rgb)
        if results_fd.detections:
            for detection in results_fd.detections:
                bboxC = detection.location_data.relative_bounding_box
                x, y = int(bboxC.xmin * w), int(bboxC.ymin * h)
                w_box, h_box = int(bboxC.width * w), int(bboxC.height * h)
                face_img = frame[y:y+h_box, x:x+w_box]
                if face_img.size > 0:
                    emotion = get_emotion(face_img)
                    cv2.putText(frame, f'감정: {emotion}', (x, y-10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 200, 0), 2)
                    cv2.rectangle(frame, (x, y), (x+w_box, y+h_box), (255, 200, 0), 2)
        prev_time = now

    # 결과 시각화
    cv2.putText(frame, gaze_text, (30, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    cv2.imshow("시선 및 표정 분석", frame)

    if cv2.waitKey(1) & 0xFF == 27:  # ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 6
#       4 import numpy as np
#       5 import time
# ----> 6 from deepface import DeepFace  # ✅ DeepFace 추가
#       8 # 👁️ 눈 및 동공 좌표 인덱스
#       9 LEFT_EYE = [33, 133]
#
# ModuleNotFoundError: No module named 'deepface'

# %%
# 그라디오 잘 작동하는지 test 해봄

import gradio as gr

def greet(name):
    return f"안녕하세요, {name}님!"

iface = gr.Interface(fn=greet, inputs="text", outputs="text")

try:
    iface.launch(share=True)
except Exception as e:
    print("[Gradio 런타임 에러 발생]")
    print(e)

# %%
# gradio, 시선추적, 점수, 표정분석, 음성 받기

import os
import cv2
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import mediapipe as mp
import gradio as gr  # moved after successful imports

# ---------------------
# 1. PyTorch 모델 정의 및 로드
# ---------------------
EMOTIONS = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

class EmotionCNN(nn.Module):
    def __init__(self):
        super(EmotionCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 12 * 12, 128), nn.ReLU(),
            nn.Linear(128, len(EMOTIONS))
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

model_path = "emotion_model.pt"
if not os.path.exists(model_path):
    raise FileNotFoundError(f"모델 파일 '{model_path}'이(가) 존재하지 않습니다. 파일을 확인해주세요.")

model = EmotionCNN()
model.load_state_dict(torch.load(model_path, map_location='cpu'))
model.eval()

# ---------------------
# 2. 전처리 도구 및 설정
# ---------------------
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

mp_face = mp.solutions.face_mesh
face_mesh = mp_face.FaceMesh(refine_landmarks=True, max_num_faces=1)

# ---------------------
# 3. 실시간 점수 상태 변수
# ---------------------
emotion_score = 0
gaze_score = 0
frame_counter = 0

# ---------------------
# 4. 실시간 분석 함수
# ---------------------
def analyze(frame):
    global emotion_score, gaze_score, frame_counter

    frame_counter += 1
    display = frame.copy()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 얼굴 인식 + 감정 분석
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in faces:
        roi = gray[y:y+h, x:x+w]
        roi_resized = cv2.resize(roi, (48, 48))
        input_tensor = transform(roi_resized).unsqueeze(0)
        with torch.no_grad():
            output = model(input_tensor)
            pred = torch.argmax(output, dim=1).item()
            label = EMOTIONS[pred]
            emotion_score += pred

        cv2.rectangle(display, (x, y), (x+w, y+h), (0,255,0), 2)
        cv2.putText(display, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2)

    # 시선 응시 판단
    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = face_mesh.process(img_rgb)

    if result.multi_face_landmarks:
        h, w, _ = frame.shape
        face = result.multi_face_landmarks[0]
        left_eye = face.landmark[145]
        right_eye = face.landmark[374]
        x_mid = int((left_eye.x + right_eye.x) / 2 * w)
        if abs(x_mid - w // 2) < 80:
            gaze_score += 1
            cv2.putText(display, "✅ 응시 중", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
        else:
            cv2.putText(display, "❌ 응시 아닌", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

    # 점수 출력 (로그)
    if frame_counter % 150 == 0:
        avg_emotion = emotion_score / frame_counter
        avg_gaze = gaze_score / frame_counter
        print(f"[INFO] 감정 평균: {avg_emotion:.2f}, 응시률: {avg_gaze:.2f}")

    return display

# ---------------------
# 5. Gradio 앱 실행
# ---------------------
try:
    gr.Interface(
        fn=analyze,
        inputs=gr.Image(source="webcam", streaming=True),
        outputs="image",
        title="🌟 실시간 감정 분석 + 시선 응시 평가",
        live=True
    ).launch()
except ModuleNotFoundError as e:
    print("[ERROR] 필요한 모듈이 누락되었습니다:", e)
    print("pip install gradio opencv-python torch torchvision mediapipe numpy 등을 설치해주세요.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 37
#      35 model_path = "emotion_model.pt"
#      36 if not os.path.exists(model_path):
# ---> 37     raise FileNotFoundError(f"모델 파일 '{model_path}'이(가) 존재하지 않습니다. 파일을 확인해주세요.")
#      39 model = EmotionCNN()
#      40 model.load_state_dict(torch.load(model_path, map_location='cpu'))
#
# FileNotFoundError: 모델 파일 'emotion_model.pt'이(가) 존재하지 않습니다. 파일을 확인해주세요.

# %%
# gradio, 시선추적, 점수, 표정분석, 음성 받기 -> deepface로 감정 분석으로 바꿈
import os
import cv2
import numpy as np
import mediapipe as mp
from deepface import DeepFace
import gradio as gr

EMOTIONS = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
mp_face = mp.solutions.face_mesh
face_mesh = mp_face.FaceMesh(refine_landmarks=True, max_num_faces=1)

emotion_score = 0
gaze_score = 0
frame_counter = 0

def analyze(frame):
    global emotion_score, gaze_score, frame_counter

    frame_counter += 1
    display = frame.copy()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in faces:
        roi_color = frame[y:y+h, x:x+w]
        try:
            result = DeepFace.analyze(roi_color, actions=['emotion'], enforce_detection=False)
            label = result[0]['dominant_emotion']
            emotion_idx = EMOTIONS.index(label) if label in EMOTIONS else 0
            emotion_score += emotion_idx
        except Exception as e:
            label = "Unknown"
            print(f"[DeepFace ERROR]: {e}")
        cv2.rectangle(display, (x, y), (x+w, y+h), (0,255,0), 2)
        cv2.putText(display, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2)

    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = face_mesh.process(img_rgb)

    if result.multi_face_landmarks:
        h, w, _ = frame.shape
        face = result.multi_face_landmarks[0]
        left_eye = face.landmark[145]
        right_eye = face.landmark[374]
        x_mid = int((left_eye.x + right_eye.x) / 2 * w)
        if abs(x_mid - w // 2) < 80:
            gaze_score += 1
            cv2.putText(display, "✅ 응시 중", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
        else:
            cv2.putText(display, "❌ 응시 아닌", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

    if frame_counter % 150 == 0:
        avg_emotion = emotion_score / frame_counter
        avg_gaze = gaze_score / frame_counter
        print(f"[INFO] 감정 평균(인덱스): {avg_emotion:.2f}, 응시률: {avg_gaze:.2f}")

    return display

# Gradio 3.50.2 방식
gr.Interface(
    fn=analyze,
    inputs=gr.Image(source="webcam", streaming=True),
    outputs="image",
    title="🌟 실시간 감정 분석 (DeepFace) + 시선 응시 평가",
    live=True
).launch()
# Out:
# WARNING:tensorflow:From c:\Users\Mira\miniconda3\envs\interview_env1\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# IMPORTANT: You are using gradio version 3.23.0, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install streamlit-webrtc==0.45.0
# Out:
# Collecting streamlit-webrtc==0.45.0
#   Downloading streamlit_webrtc-0.45.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiortc<2.0.0,>=1.4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit-webrtc==0.45.0) (1.13.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit-webrtc==0.45.0) (25.0)
# Requirement already satisfied: streamlit>=0.84.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit-webrtc==0.45.0) (1.47.1)
# Requirement already satisfied: aioice<1.0.0,>=0.10.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (0.10.1)
# Requirement already satisfied: av<15.0.0,>=14.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (14.4.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (1.17.1)
# Requirement already satisfied: cryptography>=44.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (45.0.5)
# Requirement already satisfied: google-crc32c>=1.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (0.12.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (25.1.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aioice<1.0.0,>=0.10.1->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aioice<1.0.0,>=0.10.1->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (0.2.0)
# Requirement already satisfied: pycparser in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from cffi>=1.0.0->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (2.22)
# Requirement already satisfied: typing-extensions in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pyee>=13.0.0->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (4.14.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.26.4)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.3.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (10.4.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.48.1)
# Requirement already satisfied: colorama in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from click<9,>=7.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.26.0)
# Requirement already satisfied: six>=1.5 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.17.0)
# Downloading streamlit_webrtc-0.45.0-py3-none-any.whl (872 kB)
#    ---------------------------------------- 0.0/872.3 kB ? eta -:--:--
#    ---------------------------------------- 872.3/872.3 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: streamlit-webrtc
#   Attempting uninstall: streamlit-webrtc
#     Found existing installation: streamlit-webrtc 0.63.3
#     Uninstalling streamlit-webrtc-0.63.3:
#       Successfully uninstalled streamlit-webrtc-0.63.3
# Successfully installed streamlit-webrtc-0.45.0

# %%
import cv2
import mediapipe as mp
import time

# MediaPipe 얼굴 메쉬 초기화
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

# Drawing 유틸리티
mp_drawing = mp.solutions.drawing_utils
drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)

# OpenCV 웹캠 시작
cap = cv2.VideoCapture(0)

while cap.isOpened():
    start_time = time.time()  # 프레임 시작 시간 기록
    success, image = cap.read()
    if not success:
        print("카메라에서 프레임을 가져올 수 없습니다.")
        break

    # 성능을 위해 이미지 읽기 전 BGR → RGB 변환
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_rgb.flags.writeable = False

    # MediaPipe 얼굴 메쉬 추론
    results = face_mesh.process(image_rgb)

    # 다시 BGR로 변환 후 그리기 위해 writeable 설정
    image.flags.writeable = True
    image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)

    # 얼굴 랜드마크 그리기
    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            mp_drawing.draw_landmarks(
                image=image,
                landmark_list=face_landmarks,
                connections=mp_face_mesh.FACEMESH_TESSELATION,
                landmark_drawing_spec=None,
                connection_drawing_spec=drawing_spec
            )
            # print(results)
            print(results.multi_face_landmarks)
            

    ##### 시간 계산  ##############
    end_time = time.time()  # 프레임 처리 끝난 시간 기록
    elapsed_time = end_time - start_time  # 처리 시간
    fps = 1 / elapsed_time if elapsed_time > 0 else 0

    # 시간 표시
    cv2.putText(image, f"Frame Time: {elapsed_time:.3f}s | FPS: {fps:.1f}",
                (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    cv2.imshow('Frame Time Test', image)

    break

    #################################
            

    # 결과 화면 출력
    cv2.imshow('MediaPipe FaceMesh', image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 종료 처리
cap.release()
cv2.destroyAllWindows()
# Out:
# [landmark {
#   x: 0.514542103
#   y: 0.808864415
#   z: -0.0483120568
# }
# landmark {
#   x: 0.517623
#   y: 0.761680245
#   z: -0.0771900937
# }
# landmark {
#   x: 0.515282333
#   y: 0.783927321
#   z: -0.0432412922
# }
# landmark {
#   x: 0.503980041
#   y: 0.697004199
#   z: -0.0548243523
# }
# landmark {
#   x: 0.517984
#   y: 0.740835547
#   z: -0.0807978958
# }
# landmark {
#   x: 0.517355204
#   y: 0.714984655
#   z: -0.0733409673
# }
# landmark {
#   x: 0.514769197
#   y: 0.654664516
#   z: -0.0301669035
# }
# landmark {
#   x: 0.407789171
#   y: 0.642181635
#   z: 0.0182829481
# }
# landmark {
#   x: 0.513938904
#   y: 0.608848631
#   z: -0.0176640637
# }
# landmark {
#   x: 0.514049
#   y: 0.583316207
#   z: -0.0184821244
# }
# landmark {
#   x: 0.513586581
#   y: 0.492643893
#   z: 0.00569298444
# }
# landmark {
#   x: 0.514871061
#   y: 0.8194471
#   z: -0.04703914
# }
# landmark {
#   x: 0.515004516
#   y: 0.832656145
#   z: -0.042534627
# }
# landmark {
#   x: 0.515028119
#   y: 0.843196452
#   z: -0.0356104299
# }
# landmark {
#   x: 0.515159249
#   y: 0.849719286
#   z: -0.0344261713
# }
# landmark {
#   x: 0.515739799
#   y: 0.862943113
#   z: -0.0365458019
# }
# landmark {
#   x: 0.516113043
#   y: 0.880037844
#   z: -0.0398741923
# }
# landmark {
#   x: 0.516371131
#   y: 0.897547543
#   z: -0.0380798467
# }
# landmark {
#   x: 0.513794184
#   y: 0.918321609
#   z: -0.024819281
# }
# landmark {
#   x: 0.516828597
#   y: 0.772914588
#   z: -0.0705772489
# }
# landmark {
#   x: 0.502478957
#   y: 0.773122132
#   z: -0.0523286797
# }
# landmark {
#   x: 0.353441119
#   y: 0.580052853
#   z: 0.0877736211
# }
# landmark {
#   x: 0.450043797
#   y: 0.660434902
#   z: 0.00536647299
# }
# landmark {
#   x: 0.435632885
#   y: 0.661813736
#   z: 0.0051343767
# }
# landmark {
#   x: 0.42109558
#   y: 0.661737144
#   z: 0.00812271517
# }
# landmark {
#   x: 0.401481241
#   y: 0.650292
#   z: 0.0191187523
# }
# landmark {
# landmark {
#   x: 0.406644166
#   y: 0.810034454
#   z: -0.00457659829
# }
# landmark {
#   x: 0.483851194
#   y: 0.96218437
#   z: -0.0271643344
# }
# landmark {
#   x: 0.471304268
#   y: 0.733689785
#   z: -0.0277808513
# }
# landmark {
#   x: 0.417637944
#   y: 0.908412516
#   z: 0.0051356717
# }
# landmark {
#   x: 0.436896741
#   y: 0.930508256
#   z: -0.00364787225
# }
# landmark {
#   x: 0.421737909
#   y: 0.866783559
#   z: -0.0045961
# }
# landmark {
#   x: 0.367724836
#   y: 0.821665466
#   z: 0.0407801419
# }
# landmark {
#   x: 0.401414394
#   y: 0.869803905
#   z: 0.0088232914
# }
# landmark {
#   x: 0.356723368
#   y: 0.839257538
#   z: 0.0716676638
# }
# landmark {
#   x: 0.428250909
#   y: 0.827640712
#   z: -0.0131575884
# }
# landmark {
#   x: 0.481419981
#   y: 0.703762233
#   z: -0.0255906153
# }
# landmark {
#   x: 0.483717471
#   y: 0.758235037
#   z: -0.0599858761
# }
# landmark {
#   x: 0.474149704
#   y: 0.764946
#   z: -0.0455275103
# }
# landmark {
#   x: 0.490639478
#   y: 0.744392395
#   z: -0.0691268295
# }
# landmark {
#   x: 0.466909051
#   y: 0.610198319
#   z: 0.00285464502
# }
# landmark {
#   x: 0.441377848
#   y: 0.59648025
#   z: -0.0010591147
# }
# landmark {
#   x: 0.418911725
#   y: 0.594194591
#   z: -0.00199478981
# }
# landmark {
#   x: 0.401139677
#   y: 0.598893762
#   z: 0.00218885043
# }
# landmark {
#   x: 0.389596522
#   y: 0.608489811
#   z: 0.00995292608
# }
# landmark {
#   x: 0.384621471
#   y: 0.644294
#   z: 0.0295511354
# }
# landmark {
#   x: 0.34237352
#   y: 0.708301067
#   z: 0.0861095488
# }
# landmark {
#   x: 0.397636116
#   y: 0.674005687
#   z: 0.0171522349
# }
# landmark {
#   x: 0.413430691
#   y: 0.680586278
#   z: 0.00926951133
# }
# landmark {
#   x: 0.433869302
#   y: 0.679775834
#   z: 0.00467347261
# }
# landmark {
#   x: 0.452511609
#   y: 0.674766183
#   z: 0.00386020797
# }
# landmark {
#   x: 0.466359735
#   y: 0.668759525
#   z: 0.00499506528
# }
# landmark {
#   x: 0.475894481
#   y: 0.66293484
#   z: 0.0052733249
# }
# landmark {
#   x: 0.338342458
#   y: 0.711799741
#   z: 0.139546707
# }
# landmark {
#   x: 0.474090338
#   y: 0.77124542
#   z: -0.0387244225
# }
# landmark {
#   x: 0.492196918
#   y: 0.706801414
#   z: -0.0462765135
# }
# landmark {
#   x: 0.494638711
#   y: 0.758668542
#   z: -0.0703700855
# }
# landmark {
#   x: 0.501867771
#   y: 0.7692554
#   z: -0.0647981688
# }
# landmark {
#   x: 0.494282603
#   y: 0.762485385
#   z: -0.0636906847
# }
# landmark {
#   x: 0.478025556
#   y: 0.777716815
#   z: -0.033909224
# }
# landmark {
#   x: 0.504857481
#   y: 0.770832658
#   z: -0.0685398951
# }
# landmark {
#   x: 0.505708754
#   y: 0.776097953
#   z: -0.0521144569
# }
# landmark {
#   x: 0.47396034
#   y: 0.64627713
#   z: 0.0135481087
# }
# landmark {
#   x: 0.48313123
#   y: 0.652105868
#   z: 0.00516199088
# }
# landmark {
#   x: 0.488480926
#   y: 0.65647769
#   z: -0.00497357547
# }
# landmark {
#   x: 0.40513739
#   y: 0.634498477
#   z: 0.0169470273
# }
# landmark {
#   x: 0.393675148
#   y: 0.625556588
#   z: 0.0172267072
# }
# landmark {
#   x: 0.528259397
#   y: 0.697428524
#   z: -0.0523357652
# }
# landmark {
#   x: 0.610160589
#   y: 0.654164672
#   z: 0.0362396352
# }
# landmark {
#   x: 0.52824074
#   y: 0.773783326
#   z: -0.0503655635
# }
# landmark {
#   x: 0.64682579
#   y: 0.590685189
#   z: 0.116879947
# }
# landmark {
#   x: 0.572650731
#   y: 0.666609764
#   z: 0.0170997232
# }
# landmark {
#   x: 0.585781395
#   y: 0.66944325
#   z: 0.0191773549
# }
# landmark {
#   x: 0.598460793
#   y: 0.67064
#   z: 0.0242803786
# }
# landmark {
#   x: 0.615080416
#   y: 0.662522316
#   z: 0.0381884947
# }
# landmark {
#   x: 0.56131053
#   y: 0.661535859
#   z: 0.0175046176
# }
# landmark {
#   x: 0.592139184
#   y: 0.609567404
#   z: 0.0156595726
# }
# landmark {
#   x: 0.576464474
#   y: 0.611593485
#   z: 0.0144095458
# }
# landmark {
#   x: 0.606903672
#   y: 0.613947511
#   z: 0.0213253237
# }
# landmark {
#   x: 0.616493821
#   y: 0.623595059
#   z: 0.0277297553
# }
# landmark {
#   x: 0.625501394
#   y: 0.676647425
#   z: 0.0451983325
# }
# landmark {
#   x: 0.565514565
#   y: 0.94735384
#   z: -0.00711869728
# }
# landmark {
#   x: 0.615114808
#   y: 0.650207877
#   z: 0.0415653884
# }
# landmark {
#   x: 0.655783653
#   y: 0.674070299
#   z: 0.114089414
# }
# landmark {
#   x: 0.639311552
#   y: 0.664099574
#   z: 0.062236324
# }
# landmark {
#   x: 0.581155241
#   y: 0.752714813
#   z: -0.0030047677
# }
# landmark {
#   x: 0.531634927
#   y: 0.806077063
#   z: -0.0445239693
# }
# landmark {
#   x: 0.529789567
#   y: 0.833925724
#   z: -0.0390761159
# }
# landmark {
#   x: 0.549807668
#   y: 0.820946455
#   z: -0.0348900408
# }
# landmark {
#   x: 0.560470581
#   y: 0.837308
#   z: -0.0239364076
# }
# landmark {
#   x: 0.542556
#   y: 0.839804173
#   z: -0.0323205739
# }
# landmark {
#   x: 0.551833868
#   y: 0.84804
#   z: -0.0220795684
# }
# landmark {
#   x: 0.574187
#   y: 0.884642124
#   z: -0.00325608463
# }
# landmark {
#   x: 0.529146969
#   y: 0.761596203
#   z: -0.0750594139
# }
# landmark {
#   x: 0.531434655
#   y: 0.741726577
#   z: -0.0781058446
# }
# landmark {
#   x: 0.633176327
#   y: 0.602277517
#   z: 0.0357656851
# }
# landmark {
#   x: 0.553799689
#   y: 0.701208651
#   z: -0.00364337955
# }
# landmark {
#   x: 0.558511615
#   y: 0.760162055
#   z: -0.0366757214
# }
# landmark {
#   y: 0.878449738
#   z: -0.0370595567
# }
# landmark {
#   x: 0.530242
#   y: 0.861272573
#   z: -0.033376921
# }
# landmark {
#   x: 0.528079927
#   y: 0.849285841
#   z: -0.0313097723
# }
# landmark {
#   x: 0.547798932
#   y: 0.853843033
#   z: -0.0187223833
# }
# landmark {
#   x: 0.551174641
#   y: 0.860500813
#   z: -0.0210220236
# }
# landmark {
#   x: 0.555225134
#   y: 0.869357
#   z: -0.0234380011
# }
# landmark {
#   x: 0.558601558
#   y: 0.87921226
#   z: -0.021124851
# }
# landmark {
#   x: 0.570036292
#   y: 0.825754046
#   z: -0.0171806179
# }
# landmark {
#   x: 0.652381063
#   y: 0.763760149
#   z: 0.166976139
# }
# landmark {
#   x: 0.554233074
#   y: 0.857291579
#   z: -0.0111639975
# }
# landmark {
#   x: 0.557537258
#   y: 0.861255705
#   z: -0.0128014116
# }
# landmark {
#   x: 0.532426953
#   y: 0.784335613
#   z: -0.0382482521
# }
# landmark {
#   x: 0.551930606
#   y: 0.782258332
#   z: -0.0209343266
# }
# landmark {
#   x: 0.534164846
#   y: 0.780682504
#   z: -0.0377795137
# }
# landmark {
#   x: 0.567767859
#   y: 0.71391356
#   z: 0.00172794133
# }
# landmark {
#   x: 0.589703441
#   y: 0.728658259
#   z: 0.00693897065
# }
# landmark {
#   x: 0.560807884
#   y: 0.759767354
#   z: -0.0240143631
# }
# landmark {
#   x: 0.619561315
#   y: 0.525925398
#   z: 0.0585624464
# }
# landmark {
#   x: 0.613286674
#   y: 0.548861742
#   z: 0.0329796188
# }
# landmark {
#   x: 0.608125627
#   y: 0.556981683
#   z: 0.0125602148
# }
# landmark {
#   x: 0.563856483
#   y: 0.897098303
#   z: -0.0113265933
# }
# landmark {
#   x: 0.548390925
#   y: 0.559719741
#   z: -0.0141096674
# }
# landmark {
#   x: 0.551105082
#   y: 0.537094951
#   z: -0.000714144902
# }
# landmark {
#   x: 0.55530709
#   y: 0.496475279
#   z: 0.012793839
# }
# landmark {
#   x: 0.608971655
#   y: 0.668375373
#   z: 0.0315807424
# }
# landmark {
#   x: 0.639464259
#   y: 0.692496836
#   z: 0.0535848
# }
# landmark {
#   x: 0.553946376
#   y: 0.65607506
#   z: 0.019339269
# }
# landmark {
#   x: 0.628144145
#   y: 0.634120166
#   z: 0.041665446
# }
# landmark {
#   x: 0.54456991
#   y: 0.687371135
#   z: -0.00892251823
# }
# landmark {
#   x: 0.551262677
#   y: 0.751175225
#   z: -0.0507981814
# }
# landmark {
#   x: 0.649844646
#   y: 0.708372712
#   z: 0.069760479
# }
# landmark {
#   x: 0.631285071
#   y: 0.70446068
#   z: 0.0387072228
# }
# landmark {
#   x: 0.614651918
#   y: 0.709966123
#   z: 0.0231520161
# }
# landmark {
#   x: 0.588881969
#   y: 0.704648733
#   z: 0.0144251762
# }
# landmark {
#   x: 0.569975078
#   y: 0.694924355
#   z: 0.010060586
# }
# landmark {
#   x: 0.555712938
#   y: 0.684773
#   z: 0.00549315
# }
# landmark {
#   x: 0.527770519
#   y: 0.660001218
#   z: -0.0235759318
# }
# landmark {
#   x: 0.648362756
#   y: 0.749885
#   z: 0.062375024
# }
# landmark {
#   x: 0.636941
#   y: 0.632256389
#   z: 0.0501268655
# }
# landmark {
#   x: 0.523741126
#   y: 0.772379816
#   z: -0.0690287873
# }
# landmark {
#   x: 0.553180814
#   y: 0.720086575
#   z: -0.0111290021
# }
# landmark {
#   x: 0.653969049
#   y: 0.675916731
#   z: 0.164353028
# }
# landmark {
#   x: 0.545116782
#   y: 0.673051894
#   z: 0.00334541453
# }
# landmark {
#   x: 0.560899317
#   y: 0.761882424
#   z: -0.00968508
# }
# landmark {
#   x: 0.620451
#   y: 0.651018143
#   z: 0.0446244441
# }
# landmark {
#   x: 0.551456749
#   y: 0.738812149
#   z: -0.0444980599
# }
# landmark {
#   x: 0.649124
#   y: 0.811243176
#   z: 0.155766413
# }
# landmark {
#   x: 0.553913593
#   y: 0.649288058
#   z: 0.023882281
# }
# landmark {
#   x: 0.541253448
#   y: 0.72581476
#   z: -0.0585228428
# }
# landmark {
#   x: 0.620918691
#   y: 0.905218422
#   z: 0.0529200174
# }
# landmark {
#   x: 0.61859715
#   y: 0.928963482
#   z: 0.0776151642
# }
# landmark {
#   x: 0.657428861
#   y: 0.757375419
#   z: 0.114436902
# }
# landmark {
#   x: 0.635047078
#   y: 0.878884315
#   z: 0.0743431374
# }
# landmark {
#   x: 0.649069071
#   y: 0.633696
#   z: 0.102210976
# }
# landmark {
#   x: 0.568789482
#   y: 0.968042254
#   z: -0.000168522674
# }
# landmark {
#   x: 0.521402419
#   y: 0.777663529
#   z: -0.0511231646
# }
# landmark {
#   x: 0.564958692
#   y: 0.736022651
#   z: -0.00602013664
# }
# landmark {
#   x: 0.64915
#   y: 0.670186162
#   z: 0.0778385401
# }
# landmark {
#   x: 0.597596049
#   y: 0.657642901
#   z: 0.0262176581
# }
# landmark {
#   x: 0.586487234
#   y: 0.657300532
#   z: 0.0216253474
# }
# landmark {
#   x: 0.564487636
#   y: 0.870944083
#   z: -0.0103923297
# }
# landmark {
#   x: 0.645399
#   y: 0.790168643
#   z: 0.0630237311
# }
# landmark {
#   x: 0.542989075
#   y: 0.996744692
#   z: 0.000819927955
# }
# landmark {
#   x: 0.584136486
#   y: 0.970440507
#   z: 0.0341641456
# }
# landmark {
#   x: 0.600892186
#   y: 0.953648448
#   z: 0.0530888028
# }
# landmark {
#   x: 0.575431406
#   y: 0.655254722
#   z: 0.0200277232
# }
# landmark {
#   x: 0.56476289
#   y: 0.652469397
#   z: 0.0212654416
# }
# landmark {
#   x: 0.557605386
#   y: 0.650971651
#   z: 0.0238638781
# }
# landmark {
#   x: 0.644676805
#   y: 0.630663
#   z: 0.0661637485
# }
# landmark {
#   x: 0.566308558
#   y: 0.640614808
#   z: 0.0201432891
# }
# landmark {
#   x: 0.577710688
#   y: 0.637466073
#   z: 0.0185912885
# }
# landmark {
#   x: 0.589228392
#   y: 0.637017608
#   z: 0.0203242823
# }
# landmark {
#   x: 0.600634
#   y: 0.639634132
#   z: 0.024675576
# }
# landmark {
#   x: 0.607841372
#   y: 0.643867433
#   z: 0.0298652928
# }
# landmark {
#   x: 0.65185523
#   y: 0.629106
#   z: 0.144559249
# }
# landmark {
#   x: 0.604971886
#   y: 0.656224132
#   z: 0.0315859392
# }
# landmark {
#   x: 0.55808419
#   y: 0.812001824
#   z: -0.0244058
# }
# landmark {
#   x: 0.547588289
#   y: 0.767346323
#   z: -0.0378161445
# }
# landmark {
#   x: 0.533826113
#   y: 0.802554667
#   z: -0.0388254151
# }
# landmark {
#   x: 0.604462385
#   y: 0.93029803
#   z: 0.0351259187
# }
# landmark {
#   x: 0.58755517
#   y: 0.949309289
#   z: 0.0180459581
# }
# landmark {
#   x: 0.544239879
#   y: 0.982004642
#   z: -0.0167778302
# }
# landmark {
#   x: 0.63085556
#   y: 0.90044415
#   z: 0.107706755
# }
# landmark {
#   x: 0.557980955
#   y: 0.645543
#   z: 0.0223893821
# }
# landmark {
#   x: 0.537002861
#   y: 0.690525115
#   z: -0.0295397341
# }
# landmark {
#   x: 0.565732718
#   y: 0.985476
#   z: 0.0147705022
# }
# landmark {
#   x: 0.653309
#   y: 0.801291227
#   z: 0.10806568
# }
# landmark {
#   x: 0.539102137
#   y: 0.85058105
#   z: -0.0253714062
# }
# landmark {
#   x: 0.542259157
#   y: 0.860475183
#   z: -0.0277221501
# }
# landmark {
#   x: 0.545533717
#   y: 0.873928726
#   z: -0.0305275805
# }
# landmark {
#   x: 0.547999859
#   y: 0.889365315
#   z: -0.0290444344
# }
# landmark {
#   x: 0.550091803
#   y: 0.908552468
#   z: -0.0189945735
# }
# landmark {
#   x: 0.558535814
#   y: 0.855644226
#   z: -0.0130549585
# }
# landmark {
#   x: 0.562740326
#   y: 0.854180872
#   z: -0.0126058422
# }
# landmark {
#   x: 0.566602945
#   y: 0.851715147
#   z: -0.0120312106
# }
# landmark {
#   x: 0.578981638
#   y: 0.844338298
#   z: -0.00705890451
# }
# landmark {
#   x: 0.628842235
#   y: 0.798693657
#   z: 0.0314788707
# }
# landmark {
#   x: 0.535919964
#   y: 0.672155
#   z: -0.0152202733
# }
# landmark {
#   x: 0.543382525
#   y: 0.631354809
#   z: 0.012561827
# }
# landmark {
#   x: 0.551675797
#   y: 0.635734916
#   z: 0.0193931069
# }
# landmark {
#   x: 0.554254413
#   y: 0.856558442
#   z: -0.0116323084
# }
# landmark {
#   x: 0.630064249
#   y: 0.848711133
#   z: 0.0490686521
# }
# landmark {
#   x: 0.531202912
#   y: 0.62931186
#   z: -0.00692045689
# }
# landmark {
#   x: 0.558194757
#   y: 0.927435279
#   z: -0.0120296935
# }
# landmark {
#   x: 0.528195262
#   y: 0.679285169
#   z: -0.0392975099
# }
# landmark {
#   x: 0.546507955
#   y: 0.722365379
#   z: -0.0307679344
# }
# landmark {
#   x: 0.536927
#   y: 0.937818
#   z: -0.0222923607
# }
# landmark {
#   x: 0.588349581
#   y: 0.892547
#   z: 0.00571999187
# }
# landmark {
#   x: 0.571688414
#   y: 0.77888155
#   z: -0.00656805094
# }
# landmark {
#   x: 0.574885249
#   y: 0.912784636
#   z: -0.00289570028
# }
# landmark {
#   x: 0.601607561
#   y: 0.777930915
#   z: 0.00258943834
# }
# landmark {
#   x: 0.583782554
#   y: 0.800296
#   z: -0.00500967959
# }
# landmark {
#   x: 0.612025
#   y: 0.812326372
#   z: 0.012364177
# }
# landmark {
#   x: 0.542090476
#   y: 0.96139282
#   z: -0.0226609819
# }
# landmark {
#   x: 0.553886
#   y: 0.734907687
#   z: -0.020834
# }
# landmark {
#   x: 0.600494206
#   y: 0.907610059
#   z: 0.0196135715
# }
# landmark {
#   x: 0.583452106
#   y: 0.928806901
#   z: 0.0075489548
# }
# landmark {
#   x: 0.598539
#   y: 0.867692292
#   z: 0.0104525005
# }
# landmark {
#   x: 0.641688824
#   y: 0.824742317
#   z: 0.0647379085
# }
# landmark {
#   x: 0.615184307
#   y: 0.870595038
#   z: 0.0264550019
# }
# landmark {
#   x: 0.646928072
#   y: 0.842014194
#   z: 0.0975923091
# }
# landmark {
#   x: 0.593417168
#   y: 0.829119205
#   z: 0.000660133664
# }
# landmark {
#   x: 0.544730604
#   y: 0.705015302
#   z: -0.0196179394
# }
# landmark {
#   x: 0.546646
#   y: 0.759633899
#   z: -0.0545475669
# }
# landmark {
#   x: 0.553880572
#   y: 0.766315222
#   z: -0.0393591151
# }
# landmark {
#   x: 0.542206407
#   y: 0.745356202
#   z: -0.0648914576
# }
# landmark {
#   x: 0.554617643
#   y: 0.609855652
#   z: 0.010196602
# }
# landmark {
#   x: 0.577146947
#   y: 0.596635163
#   z: 0.00971191749
# }
# landmark {
#   x: 0.596991062
#   y: 0.595214
#   z: 0.0123231225
# }
# landmark {
#   x: 0.612937391
#   y: 0.601804256
#   z: 0.0196092129
# }
# landmark {
#   x: 0.623661101
#   y: 0.613878131
#   z: 0.0295266807
# }
# landmark {
#   x: 0.628587604
#   y: 0.657216191
#   z: 0.0508667864
# }
# landmark {
#   x: 0.65852654
#   y: 0.715229452
#   z: 0.115297146
# }
# landmark {
#   x: 0.618807
#   y: 0.684
#   z: 0.0366477072
# }
# landmark {
#   x: 0.605528295
#   y: 0.688193202
#   z: 0.0262008868
# }
# landmark {
#   x: 0.587735593
#   y: 0.686017752
#   z: 0.0185859278
# }
# landmark {
#   x: 0.570729434
#   y: 0.679910779
#   z: 0.0149017917
# }
# landmark {
#   x: 0.557543039
#   y: 0.672715425
#   z: 0.0133896349
# }
# landmark {
#   x: 0.548392415
#   y: 0.665662169
#   z: 0.0121235847
# }
# landmark {
#   x: 0.653123
#   y: 0.719733298
#   z: 0.170895696
# }
# landmark {
#   x: 0.55276078
#   y: 0.772364736
#   z: -0.0326376669
# }
# landmark {
#   x: 0.538085401
#   y: 0.707607925
#   z: -0.0419554822
# }
# landmark {
#   x: 0.538123131
#   y: 0.759559333
#   z: -0.066941984
# }
# landmark {
#   x: 0.529835701
#   y: 0.769937634
#   z: -0.0627556443
# }
# landmark {
#   x: 0.53714031
#   y: 0.763596952
#   z: -0.0601151548
# }
# landmark {
#   x: 0.548234403
#   y: 0.778519332
#   z: -0.0287748706
# }
# landmark {
#   x: 0.527777791
#   y: 0.771359324
#   z: -0.0668840483
# }
# landmark {
#   x: 0.525422096
#   y: 0.77653724
#   z: -0.050707
# }
# landmark {
#   x: 0.548939228
#   y: 0.649124265
#   z: 0.0207536407
# }
# landmark {
#   x: 0.54115355
#   y: 0.653557479
#   z: 0.010569348
# }
# landmark {
#   x: 0.536930263
#   y: 0.656396747
#   z: -0.000604966946
# }
# landmark {
#   x: 0.612021267
#   y: 0.647289038
#   z: 0.0350094214
# }
# landmark {
#   x: 0.621647418
#   y: 0.635424554
#   z: 0.0364044532
# }
# landmark {
#   x: 0.439438373
#   y: 0.635565221
#   z: 0.0122673083
# }
# landmark {
#   x: 0.45642066
#   y: 0.635483265
#   z: 0.0122673083
# }
# landmark {
#   x: 0.438914984
#   y: 0.617682636
#   z: 0.0122673083
# }
# landmark {
#   x: 0.422251612
#   y: 0.635749519
#   z: 0.0122673083
# }
# landmark {
#   x: 0.439706326
#   y: 0.653335333
#   z: 0.0122673083
# }
# landmark {
#   x: 0.589179873
#   y: 0.643708467
#   z: 0.0260794889
# }
# landmark {
#   x: 0.602941036
#   y: 0.644840479
#   z: 0.0260794889
# }
# landmark {
#   x: 0.589792073
#   y: 0.62838006
#   z: 0.0260794889
# }
# landmark {
#   x: 0.575360119
#   y: 0.642576218
#   z: 0.0260794889
# }
# landmark {
#   x: 0.58860153
#   y: 0.659033179
#   z: 0.0260794889
# }
# ]

# %%
# !pip install streamlit-webrtc==0.45.0 --no-cache-dir
# Out:
# Collecting streamlit-webrtc==0.45.0
#   Downloading streamlit_webrtc-0.45.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiortc<2.0.0,>=1.4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit-webrtc==0.45.0) (1.13.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit-webrtc==0.45.0) (25.0)
# Requirement already satisfied: streamlit>=0.84.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit-webrtc==0.45.0) (1.47.1)
# Requirement already satisfied: aioice<1.0.0,>=0.10.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (0.10.1)
# Requirement already satisfied: av<15.0.0,>=14.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (14.4.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (1.17.1)
# Requirement already satisfied: cryptography>=44.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (45.0.5)
# Requirement already satisfied: google-crc32c>=1.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (0.12.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (25.1.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aioice<1.0.0,>=0.10.1->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from aioice<1.0.0,>=0.10.1->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (0.2.0)
# Requirement already satisfied: pycparser in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from cffi>=1.0.0->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (2.22)
# Requirement already satisfied: typing-extensions in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pyee>=13.0.0->aiortc<2.0.0,>=1.4.0->streamlit-webrtc==0.45.0) (4.14.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.26.4)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.3.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (10.4.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from streamlit>=0.84.1->streamlit-webrtc==0.45.0) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.48.1)
# Requirement already satisfied: colorama in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from click<9,>=7.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (0.26.0)
# Requirement already satisfied: six>=1.5 in c:\users\mira\miniconda3\envs\interview_env1\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=0.84.1->streamlit-webrtc==0.45.0) (1.17.0)
# Downloading streamlit_webrtc-0.45.0-py3-none-any.whl (872 kB)
#    ---------------------------------------- 0.0/872.3 kB ? eta -:--:--
#    ------------------------ --------------- 524.3/872.3 kB 8.5 MB/s eta 0:00:01
#    ------------------------ --------------- 524.3/872.3 kB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 872.3/872.3 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: streamlit-webrtc
# Successfully installed streamlit-webrtc-0.45.0
